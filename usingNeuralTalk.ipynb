# %% [markdown]
# <a href="https://colab.research.google.com/github/NDANGA1/begining-PyTorch/blob/main/usingNeuralTalk.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/deep-learning-with-pytorch/ImageCaptioning.pytorch
# %cd ImageCaptioning.pytorch
# Out:
# Cloning into 'ImageCaptioning.pytorch'...
# remote: Enumerating objects: 519, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 519 (delta 0), reused 0 (delta 0), pack-reused 518 (from 1)
# Receiving objects: 100% (519/519), 206.53 MiB | 40.79 MiB/s, done.
# Resolving deltas: 100% (328/328), done.
# Updating files: 100% (28/28), done.
# /content/ImageCaptioning.pytorch

# %%
# !pip install torch torchvision pillow nltk

# %%
# !mkdir -p data/FC
# !wget -O data/FC/fc-model.pth https://github.com/deep-learning-with-pytorch/ImageCaptioning.pytorch/raw/master/data/FC/fc-model.pth
# !wget -O data/FC/fc-infos.pkl https://github.com/deep-learning-with-pytorch/ImageCaptioning.pytorch/raw/master/data/FC/fc-infos.pkl
# Out:
# --2025-11-11 17:28:16--  https://github.com/deep-learning-with-pytorch/ImageCaptioning.pytorch/raw/master/data/FC/fc-model.pth
# Resolving github.com (github.com)... 140.82.116.3
# Connecting to github.com (github.com)|140.82.116.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/deep-learning-with-pytorch/ImageCaptioning.pytorch/master/data/FC/fc-model.pth [following]
# --2025-11-11 17:28:16--  https://raw.githubusercontent.com/deep-learning-with-pytorch/ImageCaptioning.pytorch/master/data/FC/fc-model.pth
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 53604511 (51M) [application/octet-stream]
# Saving to: ‘data/FC/fc-model.pth’
#
# ...

# %%
# !mkdir -p data

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-f8944e8e-db76-4a04-889d-a51027eb6363" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f8944e8e-db76-4a04-889d-a51027eb6363">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mv pic.jpg data/

# %%
# !ls data
# Out:
# FC  imagenet_weights  pic.jpg

# %%
# !python eval.py \
  --model ./data/FC/fc-model.pth \
  --infos_path ./data/FC/fc-infos.pkl \
  --image_folder ./data
# Out:
# Traceback (most recent call last):
#   File "/content/ImageCaptioning.pytorch/eval.py", line 126, in <module>
#     loader = DataLoaderRaw({'folder_path': opt.image_folder,
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/ImageCaptioning.pytorch/dataloaderraw.py", line 40, in __init__
#     self.my_resnet.load_state_dict(torch.load('./data/imagenet_weights/'+self.cnn_model+'.pth'))
#                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 1546, in load
#     return _legacy_load(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 1792, in _legacy_load
#     return legacy_load(f)
#            ^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 1659, in legacy_load
#     raise RuntimeError(
# ...

# %%
# !sed -i "s@torch.load('./data/imagenet_weights/'+self.cnn_model+'.pth')@torch.load('./data/imagenet_weights/'+self.cnn_model+'.pth', weights_only=False)@" /content/ImageCaptioning.pytorch/dataloaderraw.py

# %%
# !python eval.py \
  --model ./data/FC/fc-model.pth \
  --infos_path ./data/FC/fc-infos.pkl \
  --image_folder ./data
# Out:
# DataLoaderRaw loading images from folder:  ./data
# 0
# listing all images in directory ./data
# DataLoaderRaw found  1  images
# /content/ImageCaptioning.pytorch/models/FCModel.py:147: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   logprobs = F.log_softmax(self.logit(output))
# /content/ImageCaptioning.pytorch/models/FCModel.py:123: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   logprobs = F.log_softmax(self.logit(output))
# cp "./data/pic.jpg" vis/imgs/img1.jpg
# image 1: a small airplane is on a runway with a sky background
# cp "./data/pic.jpg" vis/imgs/img2.jpg
# image 1: a small airplane is on a runway with a sky background
# cp "./data/pic.jpg" vis/imgs/img3.jpg
# image 1: a small airplane is on a runway with a sky background
# cp "./data/pic.jpg" vis/imgs/img4.jpg
# ...
